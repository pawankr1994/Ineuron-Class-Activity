# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Pawan\Downloads\sales_data_final.csv')

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed   120        3
# 2  Office Supplies      Storage      Tenex Box, Single Width    66        4
# 3  Office Supplies        Paper  Enermax Note Cards, Premium    45        3
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack   114        5
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
# 2       0.0   29.640           8.17            High  2011
# 3       0.5  -26.055           4.82            High  2011
# 4       0.1   37.770           4.70          Medium  2011
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df['order_date']
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
type(df['order_date'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df['profit']
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
#            ...
# 51285      4.5188
# 51286      0.4200
# 51287     12.3600
# 51288      0.5600
# 51289     -0.6048
# Name: profit, Length: 51290, dtype: float64

# %%
df['profit','year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('profit', 'year')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6284/2466105608.py in <module>
# ----> 1 df['profit','year']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: ('profit', 'year')

# %%
df[['profit','year']]
# Out:
#          profit  year
# 0      106.1400  2011
# 1       36.0360  2011
# 2       29.6400  2011
# 3      -26.0550  2011
# 4       37.7700  2011
# ...         ...   ...
# 51285    4.5188  2014
# 51286    0.4200  2014
# 51287   12.3600  2014
# 51288    0.5600  2014
# 51289   -0.6048  2014
#
# [51290 rows x 2 columns]

# %%
df[['profit']]
# Out:
#          profit
# 0      106.1400
# 1       36.0360
# 2       29.6400
# 3      -26.0550
# 4       37.7700
# ...         ...
# 51285    4.5188
# 51286    0.4200
# 51287   12.3600
# 51288    0.5600
# 51289   -0.6048
#
# [51290 rows x 1 columns]

# %%
df[['order_id', 'product_id', 'quantity']]
# Out:
#               order_id        product_id  quantity
# 0         AG-2011-2040  OFF-TEN-10000025         2
# 1        IN-2011-47883   OFF-SU-10000618         3
# 2         HU-2011-1220  OFF-TEN-10001585         4
# 3      IT-2011-3647632   OFF-PA-10001492         3
# 4        IN-2011-47883   FUR-FU-10003447         5
# ...                ...               ...       ...
# 51285   CA-2014-115427   OFF-BI-10002103         2
# 51286     MO-2014-2560  OFF-WIL-10001069         1
# 51287   MX-2014-110527   OFF-LA-10004182         3
# 51288   MX-2014-114783   OFF-LA-10000413         1
# 51289   CA-2014-156720   OFF-FA-10003472         3
#
# [51290 rows x 3 columns]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed   120        3
# 2  Office Supplies      Storage      Tenex Box, Single Width    66        4
# 3  Office Supplies        Paper  Enermax Note Cards, Premium    45        3
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack   114        5
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
# 2       0.0   29.640           8.17            High  2011
# 3       0.5  -26.055           4.82            High  2011
# 4       0.1   37.770           4.70          Medium  2011
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes == 'object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
type(df.dtypes[df.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region        product_id         category sub_category  \
# 0       Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1      Oceania   OFF-SU-10000618  Office Supplies     Supplies
# 2         EMEA  OFF-TEN-10001585  Office Supplies      Storage
# 3        North   OFF-PA-10001492  Office Supplies        Paper
# 4      Oceania   FUR-FU-10003447        Furniture  Furnishings
# ...        ...               ...              ...          ...
# 51285     West   OFF-BI-10002103  Office Supplies      Binders
# 51286   Africa  OFF-WIL-10001069  Office Supplies      Binders
# 51287  Central   OFF-LA-10004182  Office Supplies       Labels
# 51288    North   OFF-LA-10000413  Office Supplies       Labels
# 51289     West   OFF-FA-10003472  Office Supplies    Fasteners
#
#                                           product_name sales order_priority
# 0                                  Tenex Lockers, Blue   408         Medium
# 1                             Acme Trimmer, High Speed   120         Medium
# 2                              Tenex Box, Single Width    66           High
# 3                          Enermax Note Cards, Premium    45           High
# 4                           Eldon Light Bulb, Duo Pack   114         Medium
# ...                                                ...   ...            ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14         Medium
# 51286          Wilson Jones Hole Reinforcements, Clear     4         Medium
# 51287           Hon Color Coded Labels, 5000 Label Set    26         Medium
# 51288           Hon Legal Exhibit Labels, Alphabetical     7         Medium
# 51289                              Bagged Rubber Bands     3         Medium
#
# [51290 rows x 16 columns]

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# top     OFF-AR-10003651  Office Supplies      Binders      Staples     13
# freq                 35            31273         6152          227    589
#
#        order_priority
# count           51290
# unique              4
# top            Medium
# freq            29433

# %%
df.dtypes[df.dtypes == 'float64'].index
# Out:
# Index(['discount', 'profit', 'shipping_cost'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id'][1:4]
# Out:
# 1      IN-2011-47883
# 2       HU-2011-1220
# 3    IT-2011-3647632
# Name: order_id, dtype: object

# %%
df['order_id'][1:40:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...         category sub_category  \
# 0       Africa  ...  Office Supplies      Storage
# 1      Oceania  ...  Office Supplies     Supplies
# 2         EMEA  ...  Office Supplies      Storage
# 3        North  ...  Office Supplies        Paper
# 4      Oceania  ...        Furniture  Furnishings
# ...        ...  ...              ...          ...
# 51285     West  ...  Office Supplies      Binders
# 51286   Africa  ...  Office Supplies      Binders
# 51287  Central  ...  Office Supplies       Labels
# 51288    North  ...  Office Supplies       Labels
# 51289     West  ...  Office Supplies    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#        discount    profit  shipping_cost  order_priority  year
# 0           0.0  106.1400          35.46          Medium  2011
# 1           0.1   36.0360           9.72          Medium  2011
# 2           0.0   29.6400           8.17            High  2011
# 3           0.5  -26.0550           4.82            High  2011
# 4           0.1   37.7700           4.70          Medium  2011
# ...         ...       ...            ...             ...   ...
# 51285       0.2    4.5188           0.89          Medium  2014
# 51286       0.0    0.4200           0.49          Medium  2014
# 51287       0.0   12.3600           0.35          Medium  2014
# 51288       0.0    0.5600           0.20          Medium  2014
# 51289       0.2   -0.6048           0.17          Medium  2014
#
# [51290 rows x 21 columns]

# %%
df['category1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'category1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6284/3464818160.py in <module>
# ----> 1 df['category1']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'category1'

# %%
df['category1'] = 'pawan'

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... sub_category  \
# 0       Africa  ...      Storage
# 1      Oceania  ...     Supplies
# 2         EMEA  ...      Storage
# 3        North  ...        Paper
# 4      Oceania  ...  Furnishings
# ...        ...  ...          ...
# 51285     West  ...      Binders
# 51286   Africa  ...      Binders
# 51287  Central  ...       Labels
# 51288    North  ...       Labels
# 51289     West  ...    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#       discount    profit  shipping_cost  order_priority  year category1
# 0          0.0  106.1400          35.46          Medium  2011     pawan
# 1          0.1   36.0360           9.72          Medium  2011     pawan
# 2          0.0   29.6400           8.17            High  2011     pawan
# 3          0.5  -26.0550           4.82            High  2011     pawan
# 4          0.1   37.7700           4.70          Medium  2011     pawan
# ...        ...       ...            ...             ...   ...       ...
# 51285      0.2    4.5188           0.89          Medium  2014     pawan
# 51286      0.0    0.4200           0.49          Medium  2014     pawan
# 51287      0.0   12.3600           0.35          Medium  2014     pawan
# 51288      0.0    0.5600           0.20          Medium  2014     pawan
# 51289      0.2   -0.6048           0.17          Medium  2014     pawan
#
# [51290 rows x 22 columns]

# %%
df['order_id'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: order_id, Length: 51290, dtype: bool

# %%
df1 = pd.read_csv(r'C:\Users\Pawan\Downloads\Dress Sales.xlsx - Sheet1.csv')

# %%
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 495   713391965          0          0         0       560       554       544
# 496   722565148          0          0         0       875       866       861
# 497   532874347          0          0         0       734       728       726
# 498   655464934          0          0         0       254       259       261
# 499   919930954          0          0         0       538       545       558
#
#      10/9/2013 12/9/2013 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013  \
# 0         2930      3119      3204  ...      3554    3624.0      3706
# 1         1164      1558      1756  ...      2710    2942.0      3258
# 2            9        10        10  ...        11      11.0        11
# 3         1637      1723      1746  ...      1878    1892.0      1914
# 4         1570      1638      1655  ...      2032    2156.0      2252
# ..         ...       ...       ...  ...       ...       ...       ...
# 495        537       525       519  ...       400     388.0       360
# 496        854       850       844  ...       859     866.0       882
# 497        715       694       690  ...       616     597.0       586
# 498        263       268       270  ...       257     256.0       255
# 499        563       578       585  ...       628     632.0       639
#
#     30/9/2013  2/10/2013  4/10/2013  6/10/2013  8/10/2010  10/10/2013  \
# 0      3746.0     3795.0     3832.0       3897     3923.0      3985.0
# 1      3354.0     3475.0     3654.0       3911     4024.0      4125.0
# 2        11.0       11.0       11.0         11       11.0        11.0
# 3      1924.0     1929.0     1941.0       1952     1955.0      1959.0
# 4      2312.0     2387.0     2459.0       2544     2614.0      2693.0
# ..        ...        ...        ...        ...        ...         ...
# 495     364.0      372.0      377.0        380      382.0       384.0
# 496     888.0      895.0      898.0        906      913.0       919.0
# 497     569.0      561.0      555.0        551      546.0       535.0
# 498     254.0      253.0      250.0        249      249.0       249.0
# 499     645.0      651.0      655.0        660      668.0       674.0
#
#      12/10/2013
# 0          4048
# 1          4277
# 2            11
# 3          1963
# 4          2736
# ..          ...
# 495         285
# 496         931
# 497         520
# 498         248
# 499         680
#
# [500 rows x 24 columns]

# %%
df1.columns
# Out:
# Index(['Dress_ID', '29/8/2013', '31/8/2013', '2/9/2013', '4/9/2013',
#        '6/9/2013', '8/9/2013', '10/9/2013', '12/9/2013', '14/9/2013',
#        '16/9/2013', '18/9/2013', '20/9/2013', '22/9/2013', '24/9/2013',
#        '26/9/2013', '28/9/2013', '30/9/2013', '2/10/2013', '4/10/2013',
#        '6/10/2013', '8/10/2010', '10/10/2013', '12/10/2013'],
#       dtype='object')

# %%
df1['29/8/2013'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: 29/8/2013, Length: 500, dtype: bool

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... sub_category  \
# 0       Africa  ...      Storage
# 1      Oceania  ...     Supplies
# 2         EMEA  ...      Storage
# 3        North  ...        Paper
# 4      Oceania  ...  Furnishings
# ...        ...  ...          ...
# 51285     West  ...      Binders
# 51286   Africa  ...      Binders
# 51287  Central  ...       Labels
# 51288    North  ...       Labels
# 51289     West  ...    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#       discount    profit  shipping_cost  order_priority  year category1
# 0          0.0  106.1400          35.46          Medium  2011     pawan
# 1          0.1   36.0360           9.72          Medium  2011     pawan
# 2          0.0   29.6400           8.17            High  2011     pawan
# 3          0.5  -26.0550           4.82            High  2011     pawan
# 4          0.1   37.7700           4.70          Medium  2011     pawan
# ...        ...       ...            ...             ...   ...       ...
# 51285      0.2    4.5188           0.89          Medium  2014     pawan
# 51286      0.0    0.4200           0.49          Medium  2014     pawan
# 51287      0.0   12.3600           0.35          Medium  2014     pawan
# 51288      0.0    0.5600           0.20          Medium  2014     pawan
# 51289      0.2   -0.6048           0.17          Medium  2014     pawan
#
# [51290 rows x 22 columns]

# %%
df['profit']
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
#            ...
# 51285      4.5188
# 51286      0.4200
# 51287     12.3600
# 51288      0.5600
# 51289     -0.6048
# Name: profit, Length: 51290, dtype: float64

# %%
df[df['profit'] == min(df['profit'])]
# Out:
#              order_id  order_date  ship_date       ship_mode  customer_name  \
# 31884  CA-2013-108196  11/26/2013  12/3/2013  Standard Class  Cindy Stewart
#
#         segment state        country market region  ... sub_category  \
# 31884  Consumer  Ohio  United States     US   East  ...     Machines
#
#                                     product_name  sales quantity discount  \
# 31884  Cubify CubeX 3D Printer Double Head Print  4,500        5      0.7
#
#          profit  shipping_cost  order_priority  year category1
# 31884 -6599.978         451.63             Low  2013     pawan
#
# [1 rows x 22 columns]

# %%
df[df['profit'] == max(df['profit'])]
# Out:
#              order_id order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10/3/2013  10/10/2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region  ... sub_category  \
# 29530  Corporate  Indiana  United States     US  Central  ...      Copiers
#
#                                 product_name   sales quantity discount  \
# 29530  Canon imageCLASS 2200 Advanced Copier  17,500        5      0.0
#
#          profit  shipping_cost  order_priority  year category1
# 29530  8399.976         349.07          Medium  2013     pawan
#
# [1 rows x 22 columns]

# %%
df[df['profit'] == max(df['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df['country']
# Out:
# 0              Algeria
# 1            Australia
# 2              Hungary
# 3               Sweden
# 4            Australia
#              ...
# 51285    United States
# 51286          Morocco
# 51287        Nicaragua
# 51288           Mexico
# 51289    United States
# Name: country, Length: 51290, dtype: object

# %%
df['country'] == 'Sweden'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: country, Length: 51290, dtype: bool

# %%
df[df['country'] == 'Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# 168     Stuart Calhoun     Consumer  Vstra Gtaland  Sweden     EU  North
# 477         Max Ludwig  Home Office          Uppsala  Sweden     EU  North
# 1342      Todd Sumrall    Corporate  Vstra Gtaland  Sweden     EU  North
# 1554    Alice McCarthy    Corporate        Stockholm  Sweden     EU  North
# ...                ...          ...              ...     ...    ...    ...
# 50948     Trudy Glocke     Consumer        Stockholm  Sweden     EU  North
# 50949     Trudy Glocke     Consumer        Stockholm  Sweden     EU  North
# 50972     Jeremy Farry     Consumer        Stockholm  Sweden     EU  North
# 51086  Mitch Gastineau    Corporate        Stockholm  Sweden     EU  North
# 51121  Mitch Gastineau    Corporate        Stockholm  Sweden     EU  North
#
#        ... sub_category                         product_name  sales quantity  \
# 3      ...        Paper          Enermax Note Cards, Premium     45        3
# 168    ...          Art            Sanford Pens, Fluorescent     31        5
# 477    ...          Art  Boston Pencil Sharpener, Easy-Erase     91        6
# 1342   ...  Furnishings        Advantus Photo Frame, Durable     40        2
# 1554   ...       Phones                  Nokia Headset, VoIP     73        2
# ...    ...          ...                                  ...    ...      ...
# 50948  ...  Accessories        Belkin Flash Drive, Bluetooth     21        1
# 50949  ...  Furnishings        Advantus Photo Frame, Durable     20        1
# 50972  ...   Appliances       KitchenAid Refrigerator, Black  1,582        6
# 51086  ...          Art                BIC Pens, Fluorescent     31        4
# 51121  ...          Art           Sanford Highlighters, Blue      8        1
#
#       discount   profit  shipping_cost  order_priority  year category1
# 3          0.5  -26.055           4.82            High  2011     pawan
# 168        0.5  -13.650           2.16          Medium  2011     pawan
# 477        0.5  -61.650           6.64          Medium  2011     pawan
# 1342       0.6  -44.052           2.78          Medium  2011     pawan
# 1554       0.5  -11.760          22.18            High  2011     pawan
# ...        ...      ...            ...             ...   ...       ...
# 50948      0.5   -5.460           0.98          Medium  2014     pawan
# 50949      0.6  -22.026           0.98          Medium  2014     pawan
# 50972      0.5 -443.070          55.39          Medium  2014     pawan
# 51086      0.5  -10.680           8.44            High  2014     pawan
# 51121      0.5   -6.165           2.00            High  2014     pawan
#
# [203 rows x 22 columns]

# %%
len(df[df['country'] == 'Sweden'])
# Out:
# 203

# %%
df['shipping_cost']
# Out:
# 0        35.46
# 1         9.72
# 2         8.17
# 3         4.82
# 4         4.70
#          ...
# 51285     0.89
# 51286     0.49
# 51287     0.35
# 51288     0.20
# 51289     0.17
# Name: shipping_cost, Length: 51290, dtype: float64

# %%
df[df['shipping_cost']>900]
# Out:
#               order_id  order_date   ship_date     ship_mode  \
# 13891   CA-2012-124891   7/31/2012   7/31/2012      Same Day
# 20543  ES-2013-1579342   1/28/2013   1/30/2013   First Class
# 20727    IN-2013-77878    2/5/2013    2/7/2013  Second Class
# 30040    IN-2013-71249  10/17/2013  10/18/2013   First Class
# 30718     SG-2013-4320   11/5/2013   11/6/2013      Same Day
#
#           customer_name      segment            state        country  market  \
# 13891       Rick Hansen     Consumer         New York  United States      US
# 20543  Katherine Murray  Home Office           Berlin        Germany      EU
# 20727     Justin Ritter    Corporate  New South Wales      Australia    APAC
# 30040      Craig Reiter     Consumer       Queensland      Australia    APAC
# 30718       Rick Hansen     Consumer            Dakar        Senegal  Africa
#
#         region  ... sub_category  \
# 13891     East  ...  Accessories
# 20543  Central  ...       Phones
# 20727  Oceania  ...       Chairs
# 30040  Oceania  ...       Phones
# 30718   Africa  ...      Copiers
#
#                                             product_name  sales quantity  \
# 13891  Plantronics CS510 - Over-the-Head monaural Wir...  2,310        7
# 20543                     Motorola Smart Phone, Cordless  2,893        5
# 20727          Novimex Executive Leather Armchair, Black  3,709        9
# 30040                  Nokia Smart Phone, with Caller ID  5,175        9
# 30718                     Sharp Wireless Fax, High-Speed  2,833        8
#
#       discount     profit  shipping_cost  order_priority  year category1
# 13891      0.0   762.1845         933.57        Critical  2012     pawan
# 20543      0.1   -96.5400         910.16          Medium  2013     pawan
# 20727      0.1  1288.7650         923.63        Critical  2013     pawan
# 30040      0.1   919.9710         915.49          Medium  2013     pawan
# 30718      0.0   311.5200         903.04        Critical  2013     pawan
#
# [5 rows x 22 columns]

# %%
df[df['shipping_cost']>900]['country']
# Out:
# 13891    United States
# 20543          Germany
# 20727        Australia
# 30040        Australia
# 30718          Senegal
# Name: country, dtype: object

# %%
df[(df['shipping_cost']>200)&(df['shipping_cost']<300)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 58      CA-2011-167199    1/7/2011   1/11/2011  Standard Class
# 84       IN-2011-19330    1/8/2011   1/12/2011    Second Class
# 309         EN-2011-70   1/24/2011   1/24/2011        Same Day
# 586     CA-2011-127614   2/12/2011   2/16/2011  Standard Class
# 587       MO-2011-7930   2/12/2011   2/14/2011     First Class
# ...                ...         ...         ...             ...
# 50704      QA-2014-940  12/24/2014  12/28/2014  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51149  ES-2014-4675868  12/30/2014    1/2/2015     First Class
# 51228   MX-2014-116267  12/31/2014    1/3/2015    Second Class
# 51229    IN-2014-43550  12/31/2014    1/1/2015     First Class
#
#              customer_name      segment             state        country  \
# 58           Maria Etezadi  Home Office          Kentucky  United States
# 84            Nicole Fjeld  Home Office            Yunnan          China
# 309              Ann Blume    Corporate          Harjumaa        Estonia
# 586       Natalie Fritzler     Consumer          Virginia  United States
# 587           Eric Murdock     Consumer  Grand Casablanca        Morocco
# ...                    ...          ...               ...            ...
# 50704      Liz MacKendrick     Consumer         Ad Dawhah          Qatar
# 51034            Adam Hart    Corporate          Victoria      Australia
# 51149          Harry Marie    Corporate       Basel-Stadt    Switzerland
# 51228           Erica Bern    Corporate         S?o Paulo         Brazil
# 51229  Marina Lichtenstein    Corporate           Jakarta      Indonesia
#
#        market          region  ... sub_category  \
# 58         US           South  ...       Chairs
# 84       APAC      North Asia  ...     Machines
# 309      EMEA            EMEA  ...       Phones
# 586        US           South  ...       Tables
# 587    Africa          Africa  ...       Chairs
# ...       ...             ...  ...          ...
# 50704    EMEA            EMEA  ...      Copiers
# 51034    APAC         Oceania  ...   Appliances
# 51149      EU         Central  ...      Copiers
# 51228   LATAM           South  ...      Copiers
# 51229    APAC  Southeast Asia  ...    Bookcases
#
#                                   product_name  sales quantity discount  \
# 58     Global Deluxe High-Back Manager's Chair  2,574        9    0.000
# 84                     Panasonic Inkjet, White  2,174        7    0.000
# 309               Cisco Smart Phone, Full Size  1,303        2    0.000
# 586    Hon 2111 Invitation Series Corner Table  1,256        6    0.000
# 587             SAFCO Swivel Stool, Adjustable    682        4    0.000
# ...                                        ...    ...      ...      ...
# 50704                Canon Copy Machine, Laser  1,573        6    0.000
# 51034                        Hoover Stove, Red  1,535        3    0.100
# 51149              Canon Fax and Copier, Laser  1,913       10    0.000
# 51228                Canon Wireless Fax, Color  1,264        5    0.002
# 51229           Safco Library with Doors, Pine  1,091        3    0.070
#
#          profit  shipping_cost  order_priority  year category1
# 58     746.4078         258.99            High  2011     pawan
# 84     260.8200         275.52          Medium  2011     pawan
# 309    286.5600         234.73          Medium  2011     pawan
# 586     75.3732         212.94            High  2011     pawan
# 587    327.1200         201.54        Critical  2011     pawan
# ...         ...            ...             ...   ...       ...
# 50704  141.4800         207.49            High  2014     pawan
# 51034 -102.4110         255.42          Medium  2014     pawan
# 51149  899.1000         236.49        Critical  2014     pawan
# 51228  301.4660         253.25            High  2014     pawan
# 51229   46.9206         243.11            High  2014     pawan
#
# [556 rows x 22 columns]

# %%
df[(df['shipping_cost']>100) & (df['profit'] < 10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# 257            Hunter Lopez   Consumer                       Managua
# 451              Ken Heidel  Corporate                        Saxony
# 625    Christopher Martinez   Consumer              National Capital
# 626    Christopher Martinez   Consumer              National Capital
# ...                     ...        ...                           ...
# 50781            Alan Hwang   Consumer                    Washington
# 50969          Frank Hawley  Corporate               Valle del Cauca
# 50970           Harry Marie  Corporate                      Brittany
# 51034             Adam Hart  Corporate                      Victoria
# 51153          Naresj Patel   Consumer  Australian Capital Territory
#
#              country market          region  ... sub_category  \
# 8        New Zealand   APAC         Oceania  ...      Copiers
# 257        Nicaragua  LATAM         Central  ...       Tables
# 451          Germany     EU         Central  ...       Phones
# 625      Philippines   APAC  Southeast Asia  ...       Phones
# 626      Philippines   APAC  Southeast Asia  ...      Copiers
# ...              ...    ...             ...  ...          ...
# 50781  United States     US            West  ...      Storage
# 50969       Colombia  LATAM           South  ...       Tables
# 50970         France     EU         Central  ...   Appliances
# 51034      Australia   APAC         Oceania  ...   Appliances
# 51153      Australia   APAC         Oceania  ...       Chairs
#
#                                             product_name  sales quantity  \
# 8                            Hewlett Wireless Fax, Laser    912        4
# 257         Chromcraft Conference Table, Fully Assembled  2,797        6
# 451                    Motorola Signal Booster, Cordless    584        8
# 625                 Nokia Signal Booster, with Caller ID    921        9
# 626                      Brother Fax Machine, High-Speed  1,235        6
# ...                                                  ...    ...      ...
# 50781  Office Impressions Heavy Duty Welded Shelving ...  1,004        6
# 50969               Barricks Training Table, Rectangular    842        5
# 50970                    Hamilton Beach Microwave, White  1,010        4
# 51034                                  Hoover Stove, Red  1,535        3
# 51153             Harbour Creations Rocking Chair, Black    434        5
#
#       discount   profit  shipping_cost  order_priority  year category1
# 8         0.40 -319.464         107.10             Low  2011     pawan
# 257       0.20   -0.072         320.38             Low  2011     pawan
# 451       0.50  -58.560         109.14            High  2011     pawan
# 625       0.25 -172.125         128.01             Low  2011     pawan
# 626       0.35 -456.174         118.63             Low  2011     pawan
# ...        ...      ...            ...             ...   ...       ...
# 50781     0.00    0.000         121.83             Low  2014     pawan
# 50969     0.20 -200.080         120.11            High  2014     pawan
# 50970     0.10  -44.940         108.27             Low  2014     pawan
# 51034     0.10 -102.411         255.42          Medium  2014     pawan
# 51153     0.40 -166.470         124.63        Critical  2014     pawan
#
# [604 rows x 22 columns]

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# category1          object
# dtype: object

# %%
date = pd.to_datetime(df['order_date'])

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...                                     product_name sales  \
# 0       Africa  ...                              Tenex Lockers, Blue   408
# 1      Oceania  ...                         Acme Trimmer, High Speed   120
# 2         EMEA  ...                          Tenex Box, Single Width    66
# 3        North  ...                      Enermax Note Cards, Premium    45
# 4      Oceania  ...                       Eldon Light Bulb, Duo Pack   114
# ...        ...  ...                                              ...   ...
# 51285     West  ...  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14
# 51286   Africa  ...          Wilson Jones Hole Reinforcements, Clear     4
# 51287  Central  ...           Hon Color Coded Labels, 5000 Label Set    26
# 51288    North  ...           Hon Legal Exhibit Labels, Alphabetical     7
# 51289     West  ...                              Bagged Rubber Bands     3
#
#       quantity discount    profit  shipping_cost  order_priority  year  \
# 0            2      0.0  106.1400          35.46          Medium  2011
# 1            3      0.1   36.0360           9.72          Medium  2011
# 2            4      0.0   29.6400           8.17            High  2011
# 3            3      0.5  -26.0550           4.82            High  2011
# 4            5      0.1   37.7700           4.70          Medium  2011
# ...        ...      ...       ...            ...             ...   ...
# 51285        2      0.2    4.5188           0.89          Medium  2014
# 51286        1      0.0    0.4200           0.49          Medium  2014
# 51287        3      0.0   12.3600           0.35          Medium  2014
# 51288        1      0.0    0.5600           0.20          Medium  2014
# 51289        3      0.2   -0.6048           0.17          Medium  2014
#
#        category1 converted_order_date
# 0          pawan           2011-01-01
# 1          pawan           2011-01-01
# 2          pawan           2011-01-01
# 3          pawan           2011-01-01
# 4          pawan           2011-01-01
# ...          ...                  ...
# 51285      pawan           2014-12-31
# 51286      pawan           2014-12-31
# 51287      pawan           2014-12-31
# 51288      pawan           2014-12-31
# 51289      pawan           2014-12-31
#
# [51290 rows x 23 columns]

# %%
df['order_date_year'] = df['converted_order_date'].dt.year

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sales  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...   408
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   120
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...    66
# 3  Home Office        Stockholm     Sweden      EU    North  ...    45
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   114
#
#   quantity discount   profit shipping_cost  order_priority  year  category1  \
# 0        2      0.0  106.140         35.46          Medium  2011      pawan
# 1        3      0.1   36.036          9.72          Medium  2011      pawan
# 2        4      0.0   29.640          8.17            High  2011      pawan
# 3        3      0.5  -26.055          4.82            High  2011      pawan
# 4        5      0.1   37.770          4.70          Medium  2011      pawan
#
#    converted_order_date order_date_year
# 0            2011-01-01            2011
# 1            2011-01-01            2011
# 2            2011-01-01            2011
# 3            2011-01-01            2011
# 4            2011-01-01            2011
#
# [5 rows x 24 columns]

# %%
df['order_date_month'] = df['converted_order_date'].dt.month

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  category1  \
# 0      0.0  106.140         35.46         Medium  2011      pawan
# 1      0.1   36.036          9.72         Medium  2011      pawan
# 2      0.0   29.640          8.17           High  2011      pawan
# 3      0.5  -26.055          4.82           High  2011      pawan
# 4      0.1   37.770          4.70         Medium  2011      pawan
#
#    converted_order_date  order_date_year order_date_month
# 0            2011-01-01             2011                1
# 1            2011-01-01             2011                1
# 2            2011-01-01             2011                1
# 3            2011-01-01             2011                1
# 4            2011-01-01             2011                1
#
# [5 rows x 25 columns]

# %%
df['order_date_week'] = df['converted_order_date'].dt.week
# Out:
# C:\Users\Pawan\AppData\Local\Temp/ipykernel_6284/4037216944.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['order_date_week'] = df['converted_order_date'].dt.week

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# 0  106.140         35.46         Medium  2011      pawan
# 1   36.036          9.72         Medium  2011      pawan
# 2   29.640          8.17           High  2011      pawan
# 3  -26.055          4.82           High  2011      pawan
# 4   37.770          4.70         Medium  2011      pawan
#
#    converted_order_date  order_date_year  order_date_month order_date_week
# 0            2011-01-01             2011                 1              52
# 1            2011-01-01             2011                 1              52
# 2            2011-01-01             2011                 1              52
# 3            2011-01-01             2011                 1              52
# 4            2011-01-01             2011                 1              52
#
# [5 rows x 26 columns]

# %%
df[['converted_order_date','order_date_week']]
# Out:
#       converted_order_date  order_date_week
# 0               2011-01-01               52
# 1               2011-01-01               52
# 2               2011-01-01               52
# 3               2011-01-01               52
# 4               2011-01-01               52
# ...                    ...              ...
# 51285           2014-12-31                1
# 51286           2014-12-31                1
# 51287           2014-12-31                1
# 51288           2014-12-31                1
# 51289           2014-12-31                1
#
# [51290 rows x 2 columns]

# %%
df[df['order_date_year']==2012]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 8998     ID-2012-39903    1/2/2012  1/6/2012  Standard Class
# 8999     ID-2012-39903    1/2/2012  1/6/2012  Standard Class
# 9000    MX-2012-168697    1/2/2012  1/4/2012     First Class
# 9001     IN-2012-79103    1/2/2012  1/6/2012  Standard Class
# 9002    CA-2012-146262    1/2/2012  1/9/2012  Standard Class
# ...                ...         ...       ...             ...
# 19955     IR-2012-8510  12/31/2012  1/5/2013  Standard Class
# 19956     IR-2012-8510  12/31/2012  1/5/2013  Standard Class
# 19957  IT-2012-5750622  12/31/2012  1/4/2013  Standard Class
# 19958   CA-2012-156377  12/31/2012  1/5/2013  Standard Class
# 19959   CA-2012-120901  12/31/2012  1/4/2013  Standard Class
#
#           customer_name    segment           state        country market  \
# 8998     Jill Stevenson  Corporate  Sumatera Utara      Indonesia   APAC
# 8999     Jill Stevenson  Corporate  Sumatera Utara      Indonesia   APAC
# 9000   Bruce Degenhardt   Consumer    San Salvador    El Salvador  LATAM
# 9001        Andy Reiter   Consumer       Rajasthan          India   APAC
# 9002    Victoria Wilson  Corporate            Ohio  United States     US
# ...                 ...        ...             ...            ...    ...
# 19955       Darren Budd  Corporate       Kordestan           Iran   EMEA
# 19956       Darren Budd  Corporate       Kordestan           Iran   EMEA
# 19957     Craig Carroll   Consumer   Midi-Pyrnes         France     EU
# 19958       Trudy Brown   Consumer           Texas  United States     US
# 19959    Barry Gonzalez   Consumer           Texas  United States     US
#
#                region  ... discount    profit shipping_cost order_priority  \
# 8998   Southeast Asia  ...     0.17  339.8778        301.26           High
# 8999   Southeast Asia  ...     0.17  399.9765        200.90           High
# 9000          Central  ...     0.00  208.5600        117.54           High
# 9001     Central Asia  ...     0.00  115.7400         74.73           High
# 9002             East  ...     0.70 -950.4000         63.76         Medium
# ...               ...  ...      ...       ...           ...            ...
# 19955            EMEA  ...     0.00    2.1000          0.56         Medium
# 19956            EMEA  ...     0.00    3.0600          0.43         Medium
# 19957         Central  ...     0.50   -9.3300          0.38         Medium
# 19958         Central  ...     0.80   -5.8496          0.35         Medium
# 19959         Central  ...     0.20    0.5668          0.26           High
#
#        year  category1  converted_order_date  order_date_year  \
# 8998   2012      pawan            2012-01-02             2012
# 8999   2012      pawan            2012-01-02             2012
# 9000   2012      pawan            2012-01-02             2012
# 9001   2012      pawan            2012-01-02             2012
# 9002   2012      pawan            2012-01-02             2012
# ...     ...        ...                   ...              ...
# 19955  2012      pawan            2012-12-31             2012
# 19956  2012      pawan            2012-12-31             2012
# 19957  2012      pawan            2012-12-31             2012
# 19958  2012      pawan            2012-12-31             2012
# 19959  2012      pawan            2012-12-31             2012
#
#        order_date_month order_date_week
# 8998                  1               1
# 8999                  1               1
# 9000                  1               1
# 9001                  1               1
# 9002                  1               1
# ...                 ...             ...
# 19955                12               1
# 19956                12               1
# 19957                12               1
# 19958                12               1
# 19959                12               1
#
# [10962 rows x 26 columns]

# %%
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# 0  106.140         35.46         Medium  2011      pawan
# 1   36.036          9.72         Medium  2011      pawan
# 2   29.640          8.17           High  2011      pawan
# 3  -26.055          4.82           High  2011      pawan
# 4   37.770          4.70         Medium  2011      pawan
#
#    converted_order_date  order_date_year  order_date_month order_date_week
# 0            2011-01-01             2011                 1              52
# 1            2011-01-01             2011                 1              52
# 2            2011-01-01             2011                 1              52
# 3            2011-01-01             2011                 1              52
# 4            2011-01-01             2011                 1              52
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'converted_order_date', 'order_date_year',
#        'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
df['cost_to_company'] = df['discount'] + df['shipping_cost']

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...    profit shipping_cost order_priority  year category1  \
# 0       Africa  ...  106.1400         35.46         Medium  2011     pawan
# 1      Oceania  ...   36.0360          9.72         Medium  2011     pawan
# 2         EMEA  ...   29.6400          8.17           High  2011     pawan
# 3        North  ...  -26.0550          4.82           High  2011     pawan
# 4      Oceania  ...   37.7700          4.70         Medium  2011     pawan
# ...        ...  ...       ...           ...            ...   ...       ...
# 51285     West  ...    4.5188          0.89         Medium  2014     pawan
# 51286   Africa  ...    0.4200          0.49         Medium  2014     pawan
# 51287  Central  ...   12.3600          0.35         Medium  2014     pawan
# 51288    North  ...    0.5600          0.20         Medium  2014     pawan
# 51289     West  ...   -0.6048          0.17         Medium  2014     pawan
#
#        converted_order_date  order_date_year  order_date_month  \
# 0                2011-01-01             2011                 1
# 1                2011-01-01             2011                 1
# 2                2011-01-01             2011                 1
# 3                2011-01-01             2011                 1
# 4                2011-01-01             2011                 1
# ...                     ...              ...               ...
# 51285            2014-12-31             2014                12
# 51286            2014-12-31             2014                12
# 51287            2014-12-31             2014                12
# 51288            2014-12-31             2014                12
# 51289            2014-12-31             2014                12
#
#        order_date_week cost_to_company
# 0                   52           35.46
# 1                   52            9.82
# 2                   52            8.17
# 3                   52            5.32
# 4                   52            4.80
# ...                ...             ...
# 51285                1            1.09
# 51286                1            0.49
# 51287                1            0.35
# 51288                1            0.20
# 51289                1            0.37
#
# [51290 rows x 27 columns]

# %%
df['cost_to_company'].max()
# Out:
# 933.57

# %%
df[df['cost_to_company'] == max(df['cost_to_company'])]
# Out:
#              order_id order_date  ship_date ship_mode customer_name   segment  \
# 13891  CA-2012-124891  7/31/2012  7/31/2012  Same Day   Rick Hansen  Consumer
#
#           state        country market region  ...    profit shipping_cost  \
# 13891  New York  United States     US   East  ...  762.1845        933.57
#
#       order_priority  year category1  converted_order_date  order_date_year  \
# 13891       Critical  2012     pawan            2012-07-31             2012
#
#        order_date_month  order_date_week cost_to_company
# 13891                 7               31          933.57
#
# [1 rows x 27 columns]

# %%
df[df['cost_to_company'] == max(df['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
df.drop('cost_to_company')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6284/2106961039.py in <module>
# ----> 1 df.drop('cost_to_company')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['cost_to_company'] not found in axis"

# %%
df.drop('cost_to_company', axis = 1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 0       Africa  ...      0.0  106.1400         35.46         Medium  2011
# 1      Oceania  ...      0.1   36.0360          9.72         Medium  2011
# 2         EMEA  ...      0.0   29.6400          8.17           High  2011
# 3        North  ...      0.5  -26.0550          4.82           High  2011
# 4      Oceania  ...      0.1   37.7700          4.70         Medium  2011
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...      0.2    4.5188          0.89         Medium  2014
# 51286   Africa  ...      0.0    0.4200          0.49         Medium  2014
# 51287  Central  ...      0.0   12.3600          0.35         Medium  2014
# 51288    North  ...      0.0    0.5600          0.20         Medium  2014
# 51289     West  ...      0.2   -0.6048          0.17         Medium  2014
#
#        category1  converted_order_date  order_date_year  order_date_month  \
# 0          pawan            2011-01-01             2011                 1
# 1          pawan            2011-01-01             2011                 1
# 2          pawan            2011-01-01             2011                 1
# 3          pawan            2011-01-01             2011                 1
# 4          pawan            2011-01-01             2011                 1
# ...          ...                   ...              ...               ...
# 51285      pawan            2014-12-31             2014                12
# 51286      pawan            2014-12-31             2014                12
# 51287      pawan            2014-12-31             2014                12
# 51288      pawan            2014-12-31             2014                12
# 51289      pawan            2014-12-31             2014                12
#
#       order_date_week
# 0                  52
# 1                  52
# 2                  52
# 3                  52
# 4                  52
# ...               ...
# 51285               1
# 51286               1
# 51287               1
# 51288               1
# 51289               1
#
# [51290 rows x 26 columns]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
#   shipping_cost order_priority  year category1  converted_order_date  \
# 0         35.46         Medium  2011     pawan            2011-01-01
# 1          9.72         Medium  2011     pawan            2011-01-01
# 2          8.17           High  2011     pawan            2011-01-01
# 3          4.82           High  2011     pawan            2011-01-01
# 4          4.70         Medium  2011     pawan            2011-01-01
#
#    order_date_year  order_date_month  order_date_week cost_to_company
# 0             2011                 1               52           35.46
# 1             2011                 1               52            9.82
# 2             2011                 1               52            8.17
# 3             2011                 1               52            5.32
# 4             2011                 1               52            4.80
#
# [5 rows x 27 columns]

# %% [markdown]
# df = df.drop('cost_to_company', axis = 1)

# %%
df.drop('cost_to_company', axis = 1, inplace = True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 0       Africa  ...      0.0  106.1400         35.46         Medium  2011
# 1      Oceania  ...      0.1   36.0360          9.72         Medium  2011
# 2         EMEA  ...      0.0   29.6400          8.17           High  2011
# 3        North  ...      0.5  -26.0550          4.82           High  2011
# 4      Oceania  ...      0.1   37.7700          4.70         Medium  2011
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...      0.2    4.5188          0.89         Medium  2014
# 51286   Africa  ...      0.0    0.4200          0.49         Medium  2014
# 51287  Central  ...      0.0   12.3600          0.35         Medium  2014
# 51288    North  ...      0.0    0.5600          0.20         Medium  2014
# 51289     West  ...      0.2   -0.6048          0.17         Medium  2014
#
#        category1  converted_order_date  order_date_year  order_date_month  \
# 0          pawan            2011-01-01             2011                 1
# 1          pawan            2011-01-01             2011                 1
# 2          pawan            2011-01-01             2011                 1
# 3          pawan            2011-01-01             2011                 1
# 4          pawan            2011-01-01             2011                 1
# ...          ...                   ...              ...               ...
# 51285      pawan            2014-12-31             2014                12
# 51286      pawan            2014-12-31             2014                12
# 51287      pawan            2014-12-31             2014                12
# 51288      pawan            2014-12-31             2014                12
# 51289      pawan            2014-12-31             2014                12
#
#       order_date_week
# 0                  52
# 1                  52
# 2                  52
# 3                  52
# 4                  52
# ...               ...
# 51285               1
# 51286               1
# 51287               1
# 51288               1
# 51289               1
#
# [51290 rows x 26 columns]

# %%
df.drop(1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 5           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 0       Africa  ...      0.0  106.1400         35.46         Medium  2011
# 2         EMEA  ...      0.0   29.6400          8.17           High  2011
# 3        North  ...      0.5  -26.0550          4.82           High  2011
# 4      Oceania  ...      0.1   37.7700          4.70         Medium  2011
# 5      Oceania  ...      0.1   15.3420          1.80         Medium  2011
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...      0.2    4.5188          0.89         Medium  2014
# 51286   Africa  ...      0.0    0.4200          0.49         Medium  2014
# 51287  Central  ...      0.0   12.3600          0.35         Medium  2014
# 51288    North  ...      0.0    0.5600          0.20         Medium  2014
# 51289     West  ...      0.2   -0.6048          0.17         Medium  2014
#
#        category1  converted_order_date  order_date_year  order_date_month  \
# 0          pawan            2011-01-01             2011                 1
# 2          pawan            2011-01-01             2011                 1
# 3          pawan            2011-01-01             2011                 1
# 4          pawan            2011-01-01             2011                 1
# 5          pawan            2011-01-01             2011                 1
# ...          ...                   ...              ...               ...
# 51285      pawan            2014-12-31             2014                12
# 51286      pawan            2014-12-31             2014                12
# 51287      pawan            2014-12-31             2014                12
# 51288      pawan            2014-12-31             2014                12
# 51289      pawan            2014-12-31             2014                12
#
#       order_date_week
# 0                  52
# 2                  52
# 3                  52
# 4                  52
# 5                  52
# ...               ...
# 51285               1
# 51286               1
# 51287               1
# 51288               1
# 51289               1
#
# [51289 rows x 26 columns]

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 0       Africa  ...      0.0  106.1400         35.46         Medium  2011
# 1      Oceania  ...      0.1   36.0360          9.72         Medium  2011
# 2         EMEA  ...      0.0   29.6400          8.17           High  2011
# 3        North  ...      0.5  -26.0550          4.82           High  2011
# 4      Oceania  ...      0.1   37.7700          4.70         Medium  2011
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...      0.2    4.5188          0.89         Medium  2014
# 51286   Africa  ...      0.0    0.4200          0.49         Medium  2014
# 51287  Central  ...      0.0   12.3600          0.35         Medium  2014
# 51288    North  ...      0.0    0.5600          0.20         Medium  2014
# 51289     West  ...      0.2   -0.6048          0.17         Medium  2014
#
#        category1  converted_order_date  order_date_year  order_date_month  \
# 0          pawan            2011-01-01             2011                 1
# 1          pawan            2011-01-01             2011                 1
# 2          pawan            2011-01-01             2011                 1
# 3          pawan            2011-01-01             2011                 1
# 4          pawan            2011-01-01             2011                 1
# ...          ...                   ...              ...               ...
# 51285      pawan            2014-12-31             2014                12
# 51286      pawan            2014-12-31             2014                12
# 51287      pawan            2014-12-31             2014                12
# 51288      pawan            2014-12-31             2014                12
# 51289      pawan            2014-12-31             2014                12
#
#       order_date_week
# 0                  52
# 1                  52
# 2                  52
# 3                  52
# 4                  52
# ...               ...
# 51285               1
# 51286               1
# 51287               1
# 51288               1
# 51289               1
#
# [51290 rows x 26 columns]

# %%
df.drop(1, inplace = True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 5           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 0       Africa  ...      0.0  106.1400         35.46         Medium  2011
# 2         EMEA  ...      0.0   29.6400          8.17           High  2011
# 3        North  ...      0.5  -26.0550          4.82           High  2011
# 4      Oceania  ...      0.1   37.7700          4.70         Medium  2011
# 5      Oceania  ...      0.1   15.3420          1.80         Medium  2011
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...      0.2    4.5188          0.89         Medium  2014
# 51286   Africa  ...      0.0    0.4200          0.49         Medium  2014
# 51287  Central  ...      0.0   12.3600          0.35         Medium  2014
# 51288    North  ...      0.0    0.5600          0.20         Medium  2014
# 51289     West  ...      0.2   -0.6048          0.17         Medium  2014
#
#        category1  converted_order_date  order_date_year  order_date_month  \
# 0          pawan            2011-01-01             2011                 1
# 2          pawan            2011-01-01             2011                 1
# 3          pawan            2011-01-01             2011                 1
# 4          pawan            2011-01-01             2011                 1
# 5          pawan            2011-01-01             2011                 1
# ...          ...                   ...              ...               ...
# 51285      pawan            2014-12-31             2014                12
# 51286      pawan            2014-12-31             2014                12
# 51287      pawan            2014-12-31             2014                12
# 51288      pawan            2014-12-31             2014                12
# 51289      pawan            2014-12-31             2014                12
#
#       order_date_week
# 0                  52
# 2                  52
# 3                  52
# 4                  52
# 5                  52
# ...               ...
# 51285               1
# 51286               1
# 51287               1
# 51288               1
# 51289               1
#
# [51289 rows x 26 columns]

# %%
df.loc[[2,3]]
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... discount  profit  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...      0.0  29.640
# 3  Home Office  Stockholm   Sweden     EU  North  ...      0.5 -26.055
#
#   shipping_cost order_priority  year  category1  converted_order_date  \
# 2          8.17           High  2011      pawan            2011-01-01
# 3          4.82           High  2011      pawan            2011-01-01
#
#    order_date_year  order_date_month order_date_week
# 2             2011                 1              52
# 3             2011                 1              52
#
# [2 rows x 26 columns]

# %%
df.loc[2:10]
# Out:
#            order_id order_date ship_date       ship_mode     customer_name  \
# 2      HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3   IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6      CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7     IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8     ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9      IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
# 10    IN-2011-65159   1/3/2011  1/7/2011    Second Class      Larry Blacks
#
#         segment             state      country  market          region  ...  \
# 2      Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 3   Home Office         Stockholm       Sweden      EU           North  ...
# 4      Consumer   New South Wales    Australia    APAC         Oceania  ...
# 5      Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6      Consumer           Ontario       Canada  Canada          Canada  ...
# 7     Corporate   New South Wales    Australia    APAC         Oceania  ...
# 8      Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 9     Corporate            Ninawa         Iraq    EMEA            EMEA  ...
# 10     Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#    discount    profit shipping_cost order_priority  year  category1  \
# 2      0.00   29.6400          8.17           High  2011      pawan
# 3      0.50  -26.0550          4.82           High  2011      pawan
# 4      0.10   37.7700          4.70         Medium  2011      pawan
# 5      0.10   15.3420          1.80         Medium  2011      pawan
# 6      0.00    3.1200         24.10         Medium  2011      pawan
# 7      0.10  110.4120        125.32       Critical  2011      pawan
# 8      0.40 -319.4640        107.10            Low  2011      pawan
# 9      0.00  253.3200         81.26           High  2011      pawan
# 10     0.45 -122.8005         33.75           High  2011      pawan
#
#     converted_order_date  order_date_year  order_date_month order_date_week
# 2             2011-01-01             2011                 1              52
# 3             2011-01-01             2011                 1              52
# 4             2011-01-01             2011                 1              52
# 5             2011-01-01             2011                 1              52
# 6             2011-01-02             2011                 1              52
# 7             2011-01-03             2011                 1               1
# 8             2011-01-03             2011                 1               1
# 9             2011-01-03             2011                 1               1
# 10            2011-01-03             2011                 1               1
#
# [9 rows x 26 columns]

# %%
df.loc[2:10:2]
# Out:
#          order_id order_date ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4   IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6    CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159   1/3/2011  1/7/2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#    discount    profit shipping_cost order_priority  year  category1  \
# 2      0.00   29.6400          8.17           High  2011      pawan
# 4      0.10   37.7700          4.70         Medium  2011      pawan
# 6      0.00    3.1200         24.10         Medium  2011      pawan
# 8      0.40 -319.4640        107.10            Low  2011      pawan
# 10     0.45 -122.8005         33.75           High  2011      pawan
#
#     converted_order_date  order_date_year  order_date_month order_date_week
# 2             2011-01-01             2011                 1              52
# 4             2011-01-01             2011                 1              52
# 6             2011-01-02             2011                 1              52
# 8             2011-01-03             2011                 1               1
# 10            2011-01-03             2011                 1               1
#
# [5 rows x 26 columns]

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 5           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 0       Africa  ...      0.0  106.1400         35.46         Medium  2011
# 2         EMEA  ...      0.0   29.6400          8.17           High  2011
# 3        North  ...      0.5  -26.0550          4.82           High  2011
# 4      Oceania  ...      0.1   37.7700          4.70         Medium  2011
# 5      Oceania  ...      0.1   15.3420          1.80         Medium  2011
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...      0.2    4.5188          0.89         Medium  2014
# 51286   Africa  ...      0.0    0.4200          0.49         Medium  2014
# 51287  Central  ...      0.0   12.3600          0.35         Medium  2014
# 51288    North  ...      0.0    0.5600          0.20         Medium  2014
# 51289     West  ...      0.2   -0.6048          0.17         Medium  2014
#
#        category1  converted_order_date  order_date_year  order_date_month  \
# 0          pawan            2011-01-01             2011                 1
# 2          pawan            2011-01-01             2011                 1
# 3          pawan            2011-01-01             2011                 1
# 4          pawan            2011-01-01             2011                 1
# 5          pawan            2011-01-01             2011                 1
# ...          ...                   ...              ...               ...
# 51285      pawan            2014-12-31             2014                12
# 51286      pawan            2014-12-31             2014                12
# 51287      pawan            2014-12-31             2014                12
# 51288      pawan            2014-12-31             2014                12
# 51289      pawan            2014-12-31             2014                12
#
#       order_date_week
# 0                  52
# 2                  52
# 3                  52
# 4                  52
# 5                  52
# ...               ...
# 51285               1
# 51286               1
# 51287               1
# 51288               1
# 51289               1
#
# [51289 rows x 26 columns]

# %%
df.loc[0:4,['order_id','order_date','ship_date']]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.iloc[0:4, 0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.loc[0:4, 0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6284/1998670086.py in <module>
# ----> 1 df.loc[0:4, 0:3]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1174
#    1175         labels = obj._get_axis(axis)
# -> 1176         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1177
#    1178         if isinstance(indexer, slice):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5683         slice(1, 3, None)
#    5684         """
# -> 5685         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    5686
#    5687         # return a slice
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5885         start_slice = None
#    5886         if start is not None:
# -> 5887             start_slice = self.get_slice_bound(start, "left")
#    5888         if start_slice is None:
#    5889             start_slice = 0
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5795         # For datetime indices label may be a string that has to be converted
#    5796         # to datetime boundary according to its resolution.
# -> 5797         label = self._maybe_cast_slice_bound(label, side)
#    5798
#    5799         # we need to look up the label
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    5747         # reject them, if index does not contain label
#    5748         if (is_float(label) or is_integer(label)) and label not in self._values:
# -> 5749             raise self._invalid_indexer("slice", label)
#    5750
#    5751         return label
#
# TypeError: cannot do slice indexing on Index with these indexers [0] of type int

# %%
df.iloc[1:6,3:6]
# Out:
#         ship_mode    customer_name      segment
# 2    Second Class    Annie Thurman     Consumer
# 3    Second Class     Eugene Moren  Home Office
# 4  Standard Class      Joseph Holt     Consumer
# 5  Standard Class      Joseph Holt     Consumer
# 6  Standard Class  Magdelene Morse     Consumer

# %%
df.dtypes[(df.dtypes == 'float64')|(df.dtypes == 'int64')].index
# Out:
# Index(['quantity', 'discount', 'profit', 'shipping_cost', 'year',
#        'order_date_year', 'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
df[df.dtypes[(df.dtypes == 'float64')|(df.dtypes == 'int64')].index]
# Out:
#        quantity  discount    profit  shipping_cost  year  order_date_year  \
# 0             2       0.0  106.1400          35.46  2011             2011
# 2             4       0.0   29.6400           8.17  2011             2011
# 3             3       0.5  -26.0550           4.82  2011             2011
# 4             5       0.1   37.7700           4.70  2011             2011
# 5             2       0.1   15.3420           1.80  2011             2011
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             2014
# 51286         1       0.0    0.4200           0.49  2014             2014
# 51287         3       0.0   12.3600           0.35  2014             2014
# 51288         1       0.0    0.5600           0.20  2014             2014
# 51289         3       0.2   -0.6048           0.17  2014             2014
#
#        order_date_month  order_date_week
# 0                     1               52
# 2                     1               52
# 3                     1               52
# 4                     1               52
# 5                     1               52
# ...                 ...              ...
# 51285                12                1
# 51286                12                1
# 51287                12                1
# 51288                12                1
# 51289                12                1
#
# [51289 rows x 8 columns]

# %%
df2 = df[df.dtypes[(df.dtypes == 'float64')|(df.dtypes == 'int64')].index]

# %%
df2[df2>100]
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# ...                 ...              ...
# 51285               NaN              NaN
# 51286               NaN              NaN
# 51287               NaN              NaN
# 51288               NaN              NaN
# 51289               NaN              NaN
#
# [51289 rows x 8 columns]

# %%
df3 = df2[df2>100]

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, order_date_month, order_date_week]
# Index: []

# %%
df3.dropna(axis = 1)
# Out:
#        year  order_date_year
# 0      2011             2011
# 2      2011             2011
# 3      2011             2011
# 4      2011             2011
# 5      2011             2011
# ...     ...              ...
# 51285  2014             2014
# 51286  2014             2014
# 51287  2014             2014
# 51288  2014             2014
# 51289  2014             2014
#
# [51289 rows x 2 columns]

# %%
df3.dropna(thresh=4)
# Out:
#        quantity  discount    profit  shipping_cost  year  order_date_year  \
# 7           NaN       NaN  110.4120         125.32  2011             2011
# 27          NaN       NaN  609.8400         109.13  2011             2011
# 43          NaN       NaN  999.3600         191.20  2011             2011
# 58          NaN       NaN  746.4078         258.99  2011             2011
# 84          NaN       NaN  260.8200         275.52  2011             2011
# ...         ...       ...       ...            ...   ...              ...
# 51149       NaN       NaN  899.1000         236.49  2014             2014
# 51150       NaN       NaN  317.1600         184.60  2014             2014
# 51151       NaN       NaN  768.8800         155.85  2014             2014
# 51152       NaN       NaN  314.0384         139.47  2014             2014
# 51228       NaN       NaN  301.4660         253.25  2014             2014
#
#        order_date_month  order_date_week
# 7                   NaN              NaN
# 27                  NaN              NaN
# 43                  NaN              NaN
# 58                  NaN              NaN
# 84                  NaN              NaN
# ...                 ...              ...
# 51149               NaN              NaN
# 51150               NaN              NaN
# 51151               NaN              NaN
# 51152               NaN              NaN
# 51228               NaN              NaN
#
# [1941 rows x 8 columns]

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# ...                 ...              ...
# 51285               NaN              NaN
# 51286               NaN              NaN
# 51287               NaN              NaN
# 51288               NaN              NaN
# 51289               NaN              NaN
#
# [51289 rows x 8 columns]

# %%
df3.fillna(value = 4)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           4.0       4.0  106.14            4.0  2011             2011
# 2           4.0       4.0    4.00            4.0  2011             2011
# 3           4.0       4.0    4.00            4.0  2011             2011
# 4           4.0       4.0    4.00            4.0  2011             2011
# 5           4.0       4.0    4.00            4.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014             2014
# 51286       4.0       4.0    4.00            4.0  2014             2014
# 51287       4.0       4.0    4.00            4.0  2014             2014
# 51288       4.0       4.0    4.00            4.0  2014             2014
# 51289       4.0       4.0    4.00            4.0  2014             2014
#
#        order_date_month  order_date_week
# 0                   4.0              4.0
# 2                   4.0              4.0
# 3                   4.0              4.0
# 4                   4.0              4.0
# 5                   4.0              4.0
# ...                 ...              ...
# 51285               4.0              4.0
# 51286               4.0              4.0
# 51287               4.0              4.0
# 51288               4.0              4.0
# 51289               4.0              4.0
#
# [51289 rows x 8 columns]

# %%
df3.fillna(value = df3['quantity'].mean())
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# ...                 ...              ...
# 51285               NaN              NaN
# 51286               NaN              NaN
# 51287               NaN              NaN
# 51288               NaN              NaN
# 51289               NaN              NaN
#
# [51289 rows x 8 columns]

# %%
df3.fillna(value = df3['profit'].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# 5      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        order_date_year  order_date_month  order_date_week
# 0                 2011        285.710477       285.710477
# 2                 2011        285.710477       285.710477
# 3                 2011        285.710477       285.710477
# 4                 2011        285.710477       285.710477
# 5                 2011        285.710477       285.710477
# ...                ...               ...              ...
# 51285             2014        285.710477       285.710477
# 51286             2014        285.710477       285.710477
# 51287             2014        285.710477       285.710477
# 51288             2014        285.710477       285.710477
# 51289             2014        285.710477       285.710477
#
# [51289 rows x 8 columns]

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 5           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 0       Africa  ...      0.0  106.1400         35.46         Medium  2011
# 2         EMEA  ...      0.0   29.6400          8.17           High  2011
# 3        North  ...      0.5  -26.0550          4.82           High  2011
# 4      Oceania  ...      0.1   37.7700          4.70         Medium  2011
# 5      Oceania  ...      0.1   15.3420          1.80         Medium  2011
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...      0.2    4.5188          0.89         Medium  2014
# 51286   Africa  ...      0.0    0.4200          0.49         Medium  2014
# 51287  Central  ...      0.0   12.3600          0.35         Medium  2014
# 51288    North  ...      0.0    0.5600          0.20         Medium  2014
# 51289     West  ...      0.2   -0.6048          0.17         Medium  2014
#
#        category1  converted_order_date  order_date_year  order_date_month  \
# 0          pawan            2011-01-01             2011                 1
# 2          pawan            2011-01-01             2011                 1
# 3          pawan            2011-01-01             2011                 1
# 4          pawan            2011-01-01             2011                 1
# 5          pawan            2011-01-01             2011                 1
# ...          ...                   ...              ...               ...
# 51285      pawan            2014-12-31             2014                12
# 51286      pawan            2014-12-31             2014                12
# 51287      pawan            2014-12-31             2014                12
# 51288      pawan            2014-12-31             2014                12
# 51289      pawan            2014-12-31             2014                12
#
#       order_date_week
# 0                  52
# 2                  52
# 3                  52
# 4                  52
# 5                  52
# ...               ...
# 51285               1
# 51286               1
# 51287               1
# 51288               1
# 51289               1
#
# [51289 rows x 26 columns]

# %%
df.groupby('order_date_year')

# %%
df.groupby('order_date_year')['profit'].mean() # caluculate the avg profit yearwise
# Out:
# order_date_year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')['shipping_cost'].mean()
# Out:
# order_date_year
# 2011    27.149201
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df.groupby('order_date_year')['discount'].mean()
# Out:
# order_date_year
# 2011    0.148193
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df[['country','market']]
# Out:
#              country  market
# 0            Algeria  Africa
# 2            Hungary    EMEA
# 3             Sweden      EU
# 4          Australia    APAC
# 5          Australia    APAC
# ...              ...     ...
# 51285  United States      US
# 51286        Morocco  Africa
# 51287      Nicaragua   LATAM
# 51288         Mexico   LATAM
# 51289  United States      US
#
# [51289 rows x 2 columns]

# %%
df['sales']
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: object

# %%
df.sales.str.replace(',',"").astype(int)
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: int32

# %%
df['sales'] = df.sales.str.replace(',',"").astype(int)

# %%
df['sales']
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: int32

# %%
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby('order_date_year')['quantity'].mean()
# Out:
# order_date_year
# 2011    3.494498
# 2012    3.476647
# 2013    3.488369
# 2014    3.457989
# Name: quantity, dtype: float64

# %%
df.groupby('order_date_year')['discount'].sum()
# Out:
# order_date_year
# 2011    1333.294
# 2012    1548.774
# 2013    1935.522
# 2014    2512.038
# Name: discount, dtype: float64

# %%
df.groupby('order_date_year')['sales'].sum()
# Out:
# order_date_year
# 2011    2259391
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32
